# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('trimmed_df_2.csv')

# %%
corr = df.corr().sort_values('ClosePrice', ascending=False)
corr
# Out:
#                              Unnamed: 0  Unnamed: 0.1  AssessmentYear  \
# ClosePrice                    -0.097071     -0.097071       -0.011641
# ListPrice                     -0.102987     -0.102987       -0.014533
# ListingLowPrice               -0.102764     -0.102764       -0.014564
# OriginalListPrice             -0.108973     -0.108973       -0.017875
# CountyTax                     -0.048096     -0.048096        0.058520
# TotalTaxes                    -0.051082     -0.051082        0.020706
# Baths                         -0.109847     -0.109847        0.010664
# BathsFull                     -0.103082     -0.103082        0.004846
# Beds                          -0.075018     -0.075018        0.040528
# LandAssessmentAmount          -0.011676     -0.011676        0.065972
# TotalAssessment               -0.030618     -0.030618        0.044656
# Fireplaces                    -0.029636     -0.029636        0.050904
# ...
